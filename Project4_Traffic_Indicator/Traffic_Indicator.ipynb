# %% [markdown]
# # Indicators of Heavy Traffic on I-94
#
# In this project, we're going to analyze a dataset about the westbound traffic on the I-94 Interstate highway.
#
# The goal of our analysis is to determine a few indicators of heavy traffic on I-94. These indicators can be weather type, time of the day, time of the week, etc.
# The I-94 Traffic Dataset
#
# John Hogue made the dataset available that we'll be working with, and you can download it from the [UCI Machine Learning Repository.](https://archive.ics.uci.edu/ml/datasets/Metro+Interstate+Traffic+Volume)

# %%
import pandas as pd 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
traffic= pd.read_csv('Metro_Interstate_Traffic_Volume.csv')

# %%
traffic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48204 entries, 0 to 48203
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   holiday              48204 non-null  object
#  1   temp                 48204 non-null  float64
#  2   rain_1h              48204 non-null  float64
#  3   snow_1h              48204 non-null  float64
#  4   clouds_all           48204 non-null  int64
#  5   weather_main         48204 non-null  object
#  6   weather_description  48204 non-null  object
#  7   date_time            48204 non-null  object
#  8   traffic_volume       48204 non-null  int64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 3.3+ MB

# %% [markdown]
# The dataset has 48,204 rows and 9 columns, and there are no null values. Each row describes traffic and weather data for a specific hour — we have data from 2012-10-02 09:00:00 until 2018-09-30 23:00:00.
#
# A station located approximately midway between Minneapolis and Saint Paul records the traffic data (see the dataset documentation). For this station, the direction of the route is westbound (i.e., cars moving from east to west). This means that the results of our analysis will be about the westbound traffic in the proximity of the station. In other words, we should avoid generalizing our results for the entire I-94 highway.

# %%
traffic.head()
# Out:
#   holiday    temp  rain_1h  snow_1h  clouds_all weather_main  \
# 0    None  288.28      0.0      0.0          40       Clouds
# 1    None  289.36      0.0      0.0          75       Clouds
# 2    None  289.58      0.0      0.0          90       Clouds
# 3    None  290.13      0.0      0.0          90       Clouds
# 4    None  291.14      0.0      0.0          75       Clouds
#
#   weather_description            date_time  traffic_volume
# 0    scattered clouds  2012-10-02 09:00:00            5545
# 1       broken clouds  2012-10-02 10:00:00            4516
# 2     overcast clouds  2012-10-02 11:00:00            4767
# 3     overcast clouds  2012-10-02 12:00:00            5026
# 4       broken clouds  2012-10-02 13:00:00            4918

# %% [markdown]
# # Analyzing traffic volume
#
# We're going to start our analysis by examining the distribution of the traffic_volume column.

# %%
# Plot a histogram 
traffic['traffic_volume'].plot.hist()
plt.show()

# %%
traffic['traffic_volume'].describe()
# Out:
# count    48204.000000
# mean      3259.818355
# std       1986.860670
# min          0.000000
# 25%       1193.000000
# 50%       3380.000000
# 75%       4933.000000
# max       7280.000000
# Name: traffic_volume, dtype: float64

# %% [markdown]
# Between 2012-10-02 09:00:00 and 2018-09-30 23:00:00, the hourly traffic volume varied from 0 to 7,280 cars, with an average of 3,260 cars.
#
# About 25% of the time, there were only 1,193 cars or fewer passing the station each hour — this probably occurs during the night, or when a road is under construction. However, about 75% of the time, the traffic volume was four times as much (4,933 cars or more).
#
# This observation gives our analysis an interesting direction: comparing daytime data with nighttime data.

# %% [markdown]
# # Traffic Volume: Day vs. Night
#
# We'll start by dividing the dataset into two parts:
#
#    - Daytime data: hours from 7 AM to 7 PM (12 hours)
#    - Nighttime data: hours from 7 PM to 7 AM (12 hours)
#
# While this is not a perfect criterion for distinguishing between nighttime and daytime, it's a good starting point.

# %%
#Get the hours to a new column
import datetime as dt
print(traffic['date_time'].dtype)
traffic['date_time']= pd.to_datetime(traffic['date_time'])
traffic['hours']= traffic['date_time'].dt.hour
traffic['month']= traffic['date_time'].dt.month
traffic['day']= traffic['date_time'].dt.day
traffic['year']= traffic['date_time'].dt.year
traffic['dayofweek']= traffic['date_time'].dt.dayofweek
# Out:
# object

# %%
# Day traffic 7 AM to 7PM 
day_traffic = traffic[traffic['hours'].between(7,18)].copy()
#Night Traffic 7PM to 7AM 
night_traffic = traffic[~traffic['hours'].between(7,18)].copy()
print("Day Traffic ", day_traffic.shape)
print("Night Traffic",night_traffic.shape)
# Out:
# Day Traffic  (23877, 14)
# Night Traffic (24327, 14)

# %% [markdown]
# This significant difference in row numbers between day and night is due to a few hours of missing data. For instance, if you look at rows 176 and 177 (traffic.iloc[176:178]), you'll notice there's no data for two hours (4 and 5).

# %%
traffic.iloc[176:178]
# Out:
#     holiday    temp  rain_1h  snow_1h  clouds_all weather_main  \
# 176    None  281.17      0.0      0.0          90       Clouds
# 177    None  281.25      0.0      0.0          92        Clear
#
#     weather_description           date_time  traffic_volume  hours  month  \
# 176     overcast clouds 2012-10-10 03:00:00             361      3     10
# 177        sky is clear 2012-10-10 06:00:00            5875      6     10
#
#      day  year  dayofweek
# 176   10  2012          2
# 177   10  2012          2

# %% [markdown]
# # Traffic Volume: Day vs. Night (II)
# Now that we've isolated day and night, we're going to look at the histograms of traffic volume side-by-side by using a grid chart.

# %%
#plot graphs to find the high traffic hours 
plt.figure(figsize = (11,3.5))
plt.subplot(1,2,1)
plt.title("Day Traffic Volume")
plt.xlabel("Hours")
plt.xlim(-100,7500)
plt.ylim(0,8000)
day_traffic['traffic_volume'].plot.hist()


plt.subplot(1,2,2)
plt.title("Night Traffic Volume")
plt.xlabel("Hours")
plt.xlim(-100,7500)
plt.ylim(0,8000)
night_traffic['traffic_volume'].plot.hist()
plt.tight_layout()

# %%
day_traffic['traffic_volume'].describe()
# Out:
# count    23877.000000
# mean      4762.047452
# std       1174.546482
# min          0.000000
# 25%       4252.000000
# 50%       4820.000000
# 75%       5559.000000
# max       7280.000000
# Name: traffic_volume, dtype: float64

# %%
night_traffic['traffic_volume'].describe()
# Out:
# count    24327.000000
# mean      1785.377441
# std       1441.951197
# min          0.000000
# 25%        530.000000
# 50%       1287.000000
# 75%       2819.000000
# max       6386.000000
# Name: traffic_volume, dtype: float64

# %% [markdown]
# The histogram that shows the distribution of traffic volume during the day is left skewed. This means that most of the traffic volume values are high — there are 4,252 or more cars passing the station each hour 75% of the time (because 25% of values are less than 4,252).
#
# The histogram displaying the nighttime data is right skewed. This means that most of the traffic volume values are low — 75% of the time, the number of cars that passed the station each hour was less than 2,819.
#
# Although there are still measurements of over 5,000 cars per hour, the traffic at night is generally light. Our goal is to find indicators of heavy traffic, so we'll only focus on the daytime data moving forward.

# %% [markdown]
# # Time Indicators
# One of the possible indicators of heavy traffic is time. There might be more people on the road in a certain month, on a certain day, or at a certain time of day.
#
# We're going to look at a few line plots showing how the traffic volume changes according to the following:
#
# Month
# Day of the week
# Time of day

# %%
import numpy as np
day_traffic_stats = day_traffic.pivot_table(['traffic_volume'],'month',aggfunc=[np.mean])
day_traffic_stats.plot.line()
plt.show()

# %% [markdown]
# The traffic looks less heavy during cold months (November–February) and more intense during warm months (March–October), with one interesting exception: July. Is there anything special about July? Is traffic significantly less heavy in July each year?
#
# To answer the last question, let's see how the traffic volume changed each year in July.

# %%
july_day_traffic = day_traffic[day_traffic['month']==7].copy()

july_day_traffic.pivot_table(['traffic_volume'],'year',aggfunc=[np.mean]).plot.line()
plt.legend().remove()
plt.show()

july_day_traffic.pivot_table(['traffic_volume'],'day',aggfunc=[np.mean]).plot.line()
plt.legend().remove()
plt.show()

# %% [markdown]
# Typically, the traffic is pretty heavy in July, similar to the other warm months. The only exception we see is 2016, which had a high decrease in traffic volume. One possible reason for this is road construction — [this article from 2016](https://www.crainsdetroit.com/article/20160728/NEWS/160729841/weekend-construction-i-96-us-23-bridge-work-i-94-lane-closures-i-696) supports this hypothesis.
#
# As a tentative conclusion here, we can say that warm months generally show heavier traffic compared to cold months. In a warm month, you can can expect for each hour of daytime a traffic volume close to 5,000 cars.
#
# On July 4th traffic is less as it is a holiday.

# %% [markdown]
# # Time Indicators (II)
# Let's now look at a more granular indicator: day number.

# %%
day_traffic.pivot_table(['traffic_volume'],'dayofweek',aggfunc=[np.mean]).plot.line()
plt.legend().remove()
plt.show()

# %% [markdown]
# Traffic volume is significantly heavier on business days (Monday – Friday). Except for Monday, we only see values over 5,000 during business days. Traffic is lighter on weekends, with values below 4,000 cars.

# %% [markdown]
# # Time Indicators (III)¶
# Let's now see what values we have based on time of the day. The weekends, however, will drag down the average values, so we're going to look only at the averages separately.

# %%
#plot graphs to find the high traffic hours 
plt.figure(figsize = (11,3.5))
plt.subplot(1,2,1)
plt.title("Day Traffic Volume")
plt.xlabel("Hours")
plt.xlim(-100,7500)
plt.ylim(0,8000)
day_traffic['traffic_volume'].plot.hist()


plt.subplot(1,2,2)
plt.title("Night Traffic Volume")
plt.xlabel("Hours")
plt.xlim(-100,7500)
plt.ylim(0,8000)
night_traffic['traffic_volume'].plot.hist()
plt.tight_layout()
plt.show()

# %%
bussiness_days = day_traffic[day_traffic['dayofweek']<5].copy()
weekends = day_traffic[day_traffic['dayofweek']>5].copy()

# %%
by_hour_business = bussiness_days.groupby('hours').mean()
by_hour_weekend = weekends.groupby('hours').mean()

plt.figure(figsize=(11,3.5))

plt.subplot(1, 2, 1)
by_hour_business['traffic_volume'].plot.line()
plt.xlim(6,20)
plt.ylim(1500,6500)
plt.title('Traffic Volume By Hour: Monday–Friday')

plt.subplot(1, 2, 2)
by_hour_weekend['traffic_volume'].plot.line()
plt.xlim(6,20)
plt.ylim(1500,6500)
plt.title('Traffic Volume By Hour: Weekend')

plt.show()

# %% [markdown]
# At each hour of the day, the traffic volume is generally higher during business days compared to the weekends. As somehow expected, the rush hours are around 7 and 16 — when most people travel from home to work and back. We see volumes of over 6,000 cars at rush hours.
#
# To summarize, we found a few time-related indicators of heavy traffic:
#
#    - The traffic is usually heavier during warm months (March–October) compared to cold months (November–February).
#    - The traffic is usually heavier on business days compared to weekends.
#    - On business days, the rush hours are around 7 and 16.

# %% [markdown]
# # Weather Indicators
#
# Another possible indicator of heavy traffic is weather. The dataset provides us with a few useful columns about weather: temp, rain_1h, snow_1h, clouds_all, weather_main, weather_description.
#
# A few of these columns are numerical, so let's start by looking up their correlation values with traffic_volume.

# %%
day_traffic.corr()['traffic_volume']
# Out:
# temp              0.128317
# rain_1h           0.003697
# snow_1h           0.001265
# clouds_all       -0.032932
# traffic_volume    1.000000
# hours             0.172704
# month            -0.022337
# day              -0.011063
# year             -0.003557
# dayofweek        -0.416453
# Name: traffic_volume, dtype: float64

# %% [markdown]
# Temperature shows the strongest correlation with a value of just +0.13. The other relevant columns (rain_1h, snow_1h, clouds_all) don't show any strong correlation with traffic_value.
#
# Let's generate a scatter plot to visualize the correlation between temp and traffic_volume.

# %%
day_traffic.plot.scatter(y='temp',x='traffic_volume')
plt.ylim(200,320)
plt.show()

# %% [markdown]
#  We can conclude that temperature doesn't look like a solid indicator of heavy traffic.
#
# Let's now look at the other weather-related columns: weather_main and weather_description.

# %%
day_traffic[['weather_main','weather_description' ]]
day_traffic.pivot_table(['traffic_volume'],'weather_main',aggfunc=[np.mean]).plot.barh()
plt.legend().remove()
plt.show()

# %%
day_traffic.pivot_table(['traffic_volume'],'weather_description',aggfunc=[np.mean]).plot.barh(figsize=(5,10))

plt.legend().remove()
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# It looks like there are three weather types where traffic volume exceeds 5,000:
#
#   - Shower snow
#   - Light rain and snow
#   - Proximity thunderstorm with drizzle
#
# It's not clear why these weather types have the highest average traffic values — this is bad weather, but not that bad. Perhaps more people take their cars out of the garage when the weather is bad instead of riding a bike or walking.

# %% [markdown]
# # Analyze night traffic Time indicators

# %% [markdown]
# One of the possible indicators of heavy traffic is time. There might be more people on the road in a certain month, on a certain day, or at a certain time of day.
#
# We're going to look at a few line plots showing how the traffic volume changes according to the following:
#
#     Month
#     Day of the week
#     Time of day

# %%
night_traffic.pivot_table(['traffic_volume'],'hours',aggfunc=[np.mean]).plot.line()
plt.legend().remove()
plt.show()

# %%
night_traffic.pivot_table(['traffic_volume'],'month',aggfunc=[np.mean]).plot.line()
plt.legend().remove()
plt.show()

# %%
#June month night traffic 
june_night_traffic = night_traffic[night_traffic['month']==6]
june_night_traffic.pivot_table(['traffic_volume'],'year',aggfunc= [np.mean]).plot.line()
plt.legend().remove()
plt.show()

# %%
night_traffic.pivot_table(['traffic_volume'],'dayofweek',aggfunc=[np.mean]).plot.line()
plt.legend().remove()
plt.show()

# %% [markdown]
# Traffic volume is significantly heavier on business days (Monday – Friday). Except for Monday. Friday night the traffic is high which makes sense as it is a night before weekend

# %%
night_bussiness_days = night_traffic.copy()[night_traffic['dayofweek'] <5] # 4 == Friday
night_weekend = night_traffic.copy()[night_traffic['dayofweek'] > 5] # 5 = Saturday
by_hour_business_night = night_bussiness_days.groupby('hours').mean()
by_hour_weekend_night = night_weekend.groupby('hours').mean()

plt.figure(figsize=(11,3.5))

plt.subplot(1, 2, 1)
by_hour_business_night['traffic_volume'].plot.line()
plt.xlim(0,25)
plt.ylim(0,6500)
plt.title('Traffic Volume By Hour: Monday–Friday')

plt.subplot(1, 2, 2)
by_hour_weekend_night['traffic_volume'].plot.line()
plt.xlim(0,25)
plt.ylim(0,6500)
plt.title('Traffic Volume By Hour: Weekend')
# Out:
# Text(0.5, 1.0, 'Traffic Volume By Hour: Weekend')

# %% [markdown]
# At each hour of the day, the traffic volume is generally higher during business days compared to the weekends.

# %% [markdown]
# # Weather Types
#
# To start, we're going to group the data by weather_main and look at the traffic_volume averages.

# %%
#Weather types 
night_traffic.pivot_table(['traffic_volume'],'weather_main',aggfunc=[np.mean]).plot.barh()
plt.legend().remove()
plt.show()

# %%
#Weather types 
night_traffic.pivot_table(['traffic_volume'],'weather_description',aggfunc=[np.mean]).plot.barh(figsize=(5,10))
plt.legend().remove()
plt.show()

# %% [markdown]
# It looks like there are three weather types where traffic volume exceeds 2500:
#
#
#     Light intensity showe rain
#     Proximity shower rain

# %% [markdown]
# # Conclusion
#
# In this project, we tried to find a few indicators of heavy traffic on the I-94 Interstate highway. We managed to find two types of indicators:
#
#    - Time indicators
#         - The traffic is usually heavier during warm months (March–October) compared to cold months (November–February).
#         - The traffic is usually heavier on business days compared to the weekends.
#         - On business days, the rush hours are around 7 and 16.
#    - Weather indicators
#         - Shower snow
#         - Light rain and snow
#         - Proximity thunderstorm with drizzle
